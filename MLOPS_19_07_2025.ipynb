# %% [markdown]
# <a href="https://colab.research.google.com/github/madanjha/Machine-Learning/blob/main/MLOPS_19_07_2025.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
values = [24,1,2,130,250,0,0,141,1,1.2,1,1,2]

# %%
df = pd.read_csv('heart.csv')
df
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
li = list(df.columns)
li.remove('target')
print(li)
# Out:
# ['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach', 'exang', 'oldpeak', 'slope', 'ca', 'thal']

# %%
import json
import urllib.request

# %%
import json
import urllib.request
data = {
    'input_data':{
        'columns':li,
        'data':[values]
    }
}
body = json.dumps(data).encode('utf-8')
url = 'https://kabir-ws-19-07-2025-fxdki.koreacentral.inference.ml.azure.com/score' #Paste your Endpoint
api_key = ''

headers = {
    'Content-Type':'application/json',
    'Authorization':f'Bearer {api_key}'
}

req = urllib.request.Request(url,body,headers)
try:
    response = urllib.request.urlopen(req)
    result = response.read()
    print('Prediction Result: ')
    print(result.decode('utf-8'))
except urllib.error.HTTPError as error:
   print('Error: ')
   print(error.info())

# 12:47 PM.
# Out:
# Prediction Result:
# [0]
