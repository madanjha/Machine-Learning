# %% [markdown]
# <a href="https://colab.research.google.com/github/madanjha/Machine-Learning/blob/main/Gen_Ai_Basic_Api_Calls.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install google-generativeai tavily-python
# Out:
# Requirement already satisfied: google-generativeai in /usr/local/lib/python3.11/dist-packages (0.8.5)
# Collecting tavily-python
#   Downloading tavily_python-0.7.9-py3-none-any.whl.metadata (7.5 kB)
# Requirement already satisfied: google-ai-generativelanguage==0.6.15 in /usr/local/lib/python3.11/dist-packages (from google-generativeai) (0.6.15)
# Requirement already satisfied: google-api-core in /usr/local/lib/python3.11/dist-packages (from google-generativeai) (2.25.1)
# Requirement already satisfied: google-api-python-client in /usr/local/lib/python3.11/dist-packages (from google-generativeai) (2.174.0)
# Requirement already satisfied: google-auth>=2.15.0 in /usr/local/lib/python3.11/dist-packages (from google-generativeai) (2.38.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.11/dist-packages (from google-generativeai) (5.29.5)
# Requirement already satisfied: pydantic in /usr/local/lib/python3.11/dist-packages (from google-generativeai) (2.11.7)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from google-generativeai) (4.67.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.11/dist-packages (from google-generativeai) (4.14.0)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /usr/local/lib/python3.11/dist-packages (from google-ai-generativelanguage==0.6.15->google-generativeai) (1.26.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from tavily-python) (2.32.3)
# Requirement already satisfied: tiktoken>=0.5.1 in /usr/local/lib/python3.11/dist-packages (from tavily-python) (0.9.0)
# Requirement already satisfied: httpx in /usr/local/lib/python3.11/dist-packages (from tavily-python) (0.28.1)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /usr/local/lib/python3.11/dist-packages (from google-api-core->google-generativeai) (1.70.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from google-auth>=2.15.0->google-generativeai) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from google-auth>=2.15.0->google-generativeai) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.11/dist-packages (from google-auth>=2.15.0->google-generativeai) (4.9.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->tavily-python) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->tavily-python) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->tavily-python) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->tavily-python) (2025.6.15)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.11/dist-packages (from tiktoken>=0.5.1->tavily-python) (2024.11.6)
# Requirement already satisfied: httplib2<1.0.0,>=0.19.0 in /usr/local/lib/python3.11/dist-packages (from google-api-python-client->google-generativeai) (0.22.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from google-api-python-client->google-generativeai) (0.2.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /usr/local/lib/python3.11/dist-packages (from google-api-python-client->google-generativeai) (4.2.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.11/dist-packages (from httpx->tavily-python) (4.9.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx->tavily-python) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx->tavily-python) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic->google-generativeai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic->google-generativeai) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic->google-generativeai) (0.4.1)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in /usr/local/lib/python3.11/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai) (1.73.1)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in /usr/local/lib/python3.11/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai) (1.71.2)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /usr/local/lib/python3.11/dist-packages (from httplib2<1.0.0,>=0.19.0->google-api-python-client->google-generativeai) (3.2.3)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.11/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=2.15.0->google-generativeai) (0.6.1)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio->httpx->tavily-python) (1.3.1)
# Downloading tavily_python-0.7.9-py3-none-any.whl (15 kB)
# Installing collected packages: tavily-python
# Successfully installed tavily-python-0.7.9

# %%
import google.generativeai as genai
from tavily import TavilyClient

# %%
genai.configure(api_key="AIzaSyAWpm4SMe1lvHHKtYnLexLwP0NutHhcaNc")
model = genai.GenerativeModel('gemini-2.0-flash')
tavily = TavilyClient(api_key="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")

# %%
response = model.generate_content("Provide a very short response, what is ai?")

# %%
response.text
# Out:
# 'Artificial intelligence; machines mimicking human intelligence.\n'

# %%
search_result = tavily.search("latest AI news", max_results=2)
for result in search_result['results']:
  print(f"Title: {result['title']}")
  print(f"URL : {result['url']}")
  print(f"Content : {result['content'][:100]}...")
  print()
# Out:
# Title: AI News | Latest AI News, Analysis & Events
# URL : https://www.artificialintelligence-news.com/
# Content : UK and Singapore form alliance to guide AI in finance · OpenAI rejects Robinhood's unauthorised toke...
#
# Title: AI News & Artificial Intelligence | TechCrunch
# URL : https://techcrunch.com/category/artificial-intelligence/
# Content : News coverage on artificial intelligence and machine learning tech, the companies building them, and...

# %% [markdown]
# #fact check

# %%
import google.generativeai as genai
from tavily import TavilyClient
import json
from datetime import datetime

# %%
GENAI_API_KEY = "AIzaSyAWpm4SMe1lvHHKtYnLexLwP0NutHhcaNc"
genai.configure(api_key=GENAI_API_KEY)
TAVILY_API_KEY = "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"

# %%
#initilize the clinets - api module
model = genai.GenerativeModel('gemini-2.0-flash')
#some llm are mulrimodel
tavily_client = TavilyClient(api_key=TAVILY_API_KEY)

# %%
def fact_check(claim):
  print(f"Fact-Checking: {claim}")
  print(f"="*60)

  try:
    print(f"Searching for evidence....")
    search_result = tavily_client.search(
        query=claim,
        search_depth = "advanced",
        max_results=5
    )

    if not search_result.get('results'):
      print(f"No search results were found....")


    evidence = ""
    sources = []

    for i, result in enumerate(search_result.get('results',[])[:5]):
      title = result.get('title',"Unknown")
      content = result.get('content',"No content")
      url = result.get('url',"NO URL")

      evidence += f"Source : {i+1}:{title}\n{content[:400]}....\n\n"
      sources.append({'title':title, 'url':url})
    print(f"Found {len(sources)} Sources")

    #Anlaysis with gemini
    print(f"Analyzing claim.....")

    prompt = f"""
    You are a professional fact-checker. Analayze this claim against the evidence:

    CLAIM:{claim}

    EVIDENCE:{evidence}

    Provide a fact-check analysis with:

    1. VERDICT: Choose ONE of these:
        -TRUE: Claim is factually accuract
        -FALSE: Claim is factually incorrect
        -PARTIALLY TRUE: Claim has some triuth but is misleading
        -UNVERIFIED: Insufficient evidence to determine accuracy
        -OUTDATED: Claim was trye but circumstances have changed

    2. CONFIDENCE: High/Medium/Low

    3. EXPLANATION: Clear 2-3 lines sentence explanation of your verdict

    4. KEY EVIDENCE: Brief summary of the most important evidence

    keep it concise and factual
    """

    response = model.generate_content(prompt)
    analysis = response.text

    print(f"FACT CHEK RESULTS....")
    print("="*60)
    print(analysis)

    print(f"SOURCES.....")
    print(f"-"*30)
    for i, source in enumerate(sources,1):
      print(f"{i}. {source['title']}")
      print(f"  {source['url']}")

    print(f"Completed at: {datetime.now()}")
  except Exception as e:
    print(f"Error:{str(e)}")

# %%
def main():
  print("SIMPLE FACT CHEKER WITH GEMINI AND TAVILY")
  print("Type 'quit' or exit")
  print("="*60)

  while True:
    try:
      claim = input("\n Enter your claim to fact-check: ").strip()

      if claim.lower() in ['quit','q','exit']:
        print("Goodbye")
        break

      if not claim:
        print(f"Please enter the claim")
        continue

      fact_check(claim)
      print("\n" + "="*60)

    except KeyboardInterrupt:
      print("Goodbye")
      break
    except Exception as e:
      print(f"Unexpected error: {str(e)}")

if __name__ == "__main__":
  main()
# Out:
# SIMPLE FACT CHEKER WITH GEMINI AND TAVILY
# Type 'quit' or exit
# ============================================================
#
#  Enter your claim to fact-check: the earth is flat
# Fact-Checking: the earth is flat
# ============================================================
# Searching for evidence....
# Found 5 Sources
# Analyzing claim.....
# FACT CHEK RESULTS....
# ============================================================
# Here's a fact-check analysis of the claim "the earth is flat":
#
# 1.  VERDICT: FALSE
# 2.  CONFIDENCE: High
# 3.  EXPLANATION: The overwhelming scientific consensus, supported by a vast body of evidence from observation and experimentation, confirms that the Earth is an oblate spheroid (approximately spherical), not flat. The claim of a flat Earth is an archaic and disproven concept.
# 4.  KEY EVIDENCE: All provided sources either directly refute the flat Earth theory (Britannica, Wikipedia, Space.com, CNN, PubMed Central) or explain the origins and beliefs of modern flat-Earthers (Duke Chronicle, Modern flat Earth beliefs). Historians also confirm that the idea of a flat Earth was not a common belief among educated people for most of Western civilization (Source 5).
#
# SOURCES.....
# ------------------------------
# 1. Flat Earth | Theory, Model, Meaning, & Facts | Britannica
#   https://www.britannica.com/topic/flat-Earth
# 2. Flat Earth - Wikipedia
#   https://en.wikipedia.org/wiki/Flat_Earth
# 3. Modern flat Earth beliefs - Wikipedia
#   https://en.wikipedia.org/wiki/Modern_flat_Earth_beliefs
# 4. Listening to flat-earthers - Duke Chronicle
#   https://www.dukechronicle.com/article/2024/08/083124-narain-listening-to-flat-earthers
# 5. What Would Happen if the Earth Were Actually Flat?
#   https://lamont.columbia.edu/news/what-would-happen-if-earth-were-actually-flat
# Completed at: 2025-07-06 18:24:38.525548
#
# ============================================================
#
#  Enter your claim to fact-check: Ayodhaya shri Ram temple
# Fact-Checking: Ayodhaya shri Ram temple
# ============================================================
# Searching for evidence....
# Found 5 Sources
# Analyzing claim.....
# FACT CHEK RESULTS....
# ============================================================
# 1.  VERDICT: TRUE
# 2.  CONFIDENCE: High
# 3.  EXPLANATION: The claim "Ayodhya Shri Ram Temple" is accurate as the temple exists and is under construction in Ayodhya. Multiple sources confirm its location, historical significance, and recent consecration ceremony.
# 4.  KEY EVIDENCE: Sources 1, 2, 3, and 5 explicitly mention the existence and significance of the Ayodhya Ram Temple, confirming its construction and importance to Hindu devotees.
#
# SOURCES.....
# ------------------------------
# 1. Ayodhya Ram Mandir: Opening, Timings, Donation & Design [2024]
#   https://themetrorailguy.com/ayodhya-ram-mandir-information-design-status-updates/
# 2. Ram Mandir - Wikipedia
#   https://en.wikipedia.org/wiki/Ram_Mandir
# 3. Ayodhya Ram Mandir: History, Architecture and Significance - SOTC
#   https://www.sotc.in/blog/indian-holidays/ayodhya-ram-mandir-history-architecture-and-significance
# 4. Ayodhya Ram temple completion delayed by three months, says ...
#   https://www.hindustantimes.com/india-news/ayodhya-ram-temple-completion-delayed-by-three-months-says-construction-panel-chief-101731148638961.html
# 5. Ayodhya Ram Temple: A Symbol of Faith and Cultural Heritage
#   https://www.thomascook.in/blog/india-holidays/ayodhya-ram-temple-a-symbol-of-faith-and-cultural-heritage/
# Completed at: 2025-07-06 18:25:19.958693
#
# ============================================================
#
#  Enter your claim to fact-check:  India won 12 gold medals in olympics in 2025
# Fact-Checking: India won 12 gold medals in olympics in 2025
# ============================================================
# Searching for evidence....
# Found 5 Sources
# Analyzing claim.....
# FACT CHEK RESULTS....
# ============================================================
# 1.  VERDICT: FALSE
# 2.  CONFIDENCE: High
# 3.  EXPLANATION: The claim states that India won 12 gold medals in the Olympics in 2025, but the provided sources show that India won 8 gold medals at the Special Olympics World Winter Games 2025 and that the Indian team won 12 medals at the Olympics 2024. Also, India won 7 gold medals at the Khelo India Winter Games 2025.
# 4.  KEY EVIDENCE: Sources 1 and 2 state India won 8 gold medals at the Special Olympics World Winter Games 2025. Source 3 reports India won 7 gold medals at the Khelo India Winter Games 2025. Source 4 reports India won 12 medals at the Olympics 2024.
#
# SOURCES.....
# ------------------------------
# 1. India Concludes Special Olympics World Winter Games 2025 With 33 Medals
#   https://affairscloud.com/india-concludes-special-olympics-world-winter-games-2025-with-33-medals/
# 2. India Shines with 33 Medals at the Special Olympics World ... - adda247
#   https://currentaffairs.adda247.com/india-shines-with-33-medals-at-the-special-olympics-world-winter-games-2025/
# 3. Khelo India Winter Games 2025 medal tally - full list - Olympics.com
#   https://www.olympics.com/en/news/khelo-india-winter-games-kiwg-2025-medal-tally-table-winners-list
# 4. Olympic Gold Medalist in India List: Incredible Achievements in 2025
#   https://www.cheggindia.com/general-knowledge/olympic-gold-medalist-in-india-list/
# 5. National Games 2025 medal tally - full table - Olympics.com
#   https://www.olympics.com/en/news/national-games-2025-medal-tally-table
# Completed at: 2025-07-06 18:26:11.900278
#
# ============================================================
#
#  Enter your claim to fact-check: q
# Goodbye

# %% [markdown]
# ##*Travel buddy*

# %%
class TravelPlanningAssistant:
  def __init__(self):
    self.destination = ""
    self.duration = ""
    self.budget = ""
    self.interests = [] #array not a str
    self.travel_style = ""

  def get_travel_info(self):
    print(f"Welcome to Travel buddy...")
    print("="*60)

    self.destination = input("Where do you want to go? ").strip()
    self.duration = input("How many days? ").strip()
    self.budget = input("What's your budget range? (500-1000, midrange, luxury)").strip()

    print(f"\nWhat are you interested in? (seperate with commas)")
    print("Examples : food, culture, adventure, nature, shopping, history")
    interests_input = input("Interest: ").strip()
    self.interests = [interest.strip() for interest in interests_input.split(',') if interest.strip()]

    print("\nTravel Style")
    print(f"1. Backpacker/Budget")
    print(f"2. Comfort/Mid-range")
    print(f"3. Luxury")
    print(f"4. Adventure")
    print(f"5. Cultural/Historical")
    style_choice = input("Choose (1-5): ").strip()

    styles= {
        "1":"Backpacker/Budget",
        "2":"Comfort/Mid-range",
        "3":"Luxury",
        "4":"Adventure",
        "5":"Cultural/Historical"
    }

    self.travel_style = styles.get(style_choice,"mid-range")

  def research_desitination(self):
    print(f"\n Researching Destination {self.destination}...")

    research_queries = [
        f"{self.destination} travel guide 2025-2026",
        f"{self.destination} best attractions things to do",
        f"{self.destination} travel safety current situation",
        f"{self.destination} weather climate best time to visit",
        f"{self.destination} budget costs accomodation and food",
    ]

    all_research = {}

    for query in research_queries:
      try:
        print(f"Searching : {query}....")
        results = tavily_client.search(query=query, max_results=3)
        research_text = ""
        for result in results.get('results',[]):
          research_text += f"Sources : {result.get('title','Unknown')}\n"
          research_text += f"{result.get('content','No Content')}\n\n"
        all_research[query] = research_text
      except Exception as e:
        print(f"Error Searching : {query}: {str(e)}")
        all_research[query] = "No information available"
    return all_research

  def create_travel_plan(self, research_data):
    print(f"Creating your personalizd travel plan....")

    combined_research = ""
    for query, content in research_data.items():
      combined_research += f"=== {query} ===\n{content}\n\n"

    prompt = f"""
    You are an expert travel planner. Create a comprehensive and detailed travel plan based on:

    DESTINATION : {self.destination}
    DURATION: {self.duration}
    BUDGET:{self.budget}
    INTERESTS:{self.interests}
    TRAVEL_STYLE:{self.travel_style}

    RESEARCH DATA: {combined_research[:8000]}

    Create a detailed plan with:

    1.**DESTINATION OVERVIEW**
      -Brief description and highlights
      -Best time time to visit
      -Cultural tips and etiquette

    2.**SAFETY & PRACTICAL INFO**
      -Current safety situation
      -Visa Requirements
      -Currency exchange and payment method
      - Language Tips

    3. **DAILY ITENARY**
      -Day-by-day plan for {self.destination}
      -Mix of must-see attractions and personal interests
      -Include travel time between locations

    4.**FOOD AVAILABE**
      -Country specific cusisine information
      -Veg food vs Non-veg food based information for veg or vegal travellers

    5. **EMERGENCY CONTACT**
      -Imporatant phone numbers
      -Embassy/consulate info

    Make it practical, detailed, and personalized to their interests and budget
    """

    try:
      response = model.generate_content(prompt)
      return response.text
    except Exception as e:
      print(f"Error creating travel plan : {str(e)}")

  def get_current_alerts(self):
    print(f"Checking current travel alerts... Travel advisory")
    try:
      alert_query = f"{self.destination} travel advisory warning alert 2025 2026"
      result = tavily_client.search(query=alert_query, max_results=3)

      alerts = ""
      for result in results.get('results',[]):
        alerts += f"⚠️ {result.get('title','Unknown')}\n"
        alerts += f"⚠️ {result.get('content','No Content')[:200]}\n\n"
      return alerts if alerts else "No current travel alerts found!!"
    except Exception as e:
      return f"Eroor checking alerts: {e}"

  def run(self):
    try:
      self.get_travel_info()
      research_data = self.research_desitination()
      alerts = self.get_current_alerts()

      travel_plan = self.create_travel_plan(research_data)

      print("\n" + "="*60)
      print(f"Your personalized travel plan is.....")
      print("="*60)
      print(travel_plan)

      print("\n" + "="*60)
      print(f"Current travel alerts.....")
      print("="*60)
      print(alerts)

      print("\n" + "="*60)
      print(f"Travel Summary ")
      print(f"Destination : {self.destination}")
      print(f"Duration : {self.duration}")
      print(f"Budget : {self.budget}")
      print(f"Interests : {self.interests}")
      print(f"Style : {self.travel_style}")

      save = input("\n Save this plan to file? (y/n): ").strip().lower()
      if save == 'y':
            filename = f"{travel_plan_my_file}.txt"
            with open(filename, 'w', encoding='utf-8') as f:
                f.write(f"Travel plan")
                f.write(travel_plan)
                f.write(alerts)
            print(f"Plan saved")
    except Exception as e:
            pass

# %%
def main():
  assistant = TravelPlanningAssistant()

  while True:
    try:
      assistant.run()

      another = input("\n Plan another trip (y/n) : ").strip().lower()
      if another != 'y':
        print(f"Happy travels!")
        break
      assistant = TravelPlanningAssistant()
    except Exception as e:
      print(f"Goodbye")
      break

if __name__ == "__main__":
  main()
# Out:
# Welcome to Travel buddy...
# ============================================================
# Where do you want to go? Bhutan
# How many days? 4
# What's your budget range? (500-1000, midrange, luxury)2000
#
# What are you interested in? (seperate with commas)
# Examples : food, culture, adventure, nature, shopping, history
# Interest: Adaenture
#
# Travel Style
# 1. Backpacker/Budget
# 2. Comfort/Mid-range
# 3. Luxury
# 4. Adventure
# 5. Cultural/Historical
# Choose (1-5): comfort
#
#  Researching Destination Bhutan...
# Searching : Bhutan travel guide 2025-2026....
# Searching : Bhutan best attractions things to do....
# Searching : Bhutan travel safety current situation....
# Searching : Bhutan weather climate best time to visit....
# Searching : Bhutan budget costs accomodation and food....
# Checking current travel alerts... Travel advisory
# Creating your personalizd travel plan....
#
# ============================================================
# Your personalized travel plan is.....
# ============================================================
# Okay, here's a detailed 4-day Bhutan itinerary tailored for an adventure-seeking traveler with a mid-range budget of $2000, based on the provided research data:
#
# **1. DESTINATION OVERVIEW**
#
# *   **Brief Description:** Bhutan, the "Land of the Thunder Dragon," is a kingdom nestled in the Himalayas, renowned for its stunning landscapes, unique culture, and emphasis on Gross National Happiness (GNH). It's a destination that offers a blend of ancient traditions and modern development, with vibrant monasteries, imposing fortresses (Dzongs), and breathtaking hiking trails.
#
# *   **Highlights:**
#     *   **Tiger's Nest Monastery (Paro Taktsang):**  Bhutan's most iconic landmark, a cliffside monastery offering incredible views and a challenging but rewarding hike.
#     *   **Punakha Dzong:**  A strategically located and beautifully decorated fortress at the confluence of two rivers.
#     *   **Thimphu:** The capital city, a blend of modern life and traditional Bhutanese architecture.
#     *   **Suspension Bridges:** Experience Bhutan's impressive engineering feats with its longest suspension bridge.
#
# *   **Best Time to Visit:** Spring (March-May) and Autumn (September-November) are ideal. The weather is pleasant, skies are clear, and you can experience major Bhutanese festivals (though festivals can affect pricing).
#
# *   **Cultural Tips & Etiquette:**
#     *   **Dress respectfully:**  Cover shoulders and knees when visiting temples and Dzongs.
#     *   **Remove shoes:** Before entering temples, Dzongs, and some homes.
#     *   **Clockwise direction:** Circumambulate temples, monasteries, and prayer wheels in a clockwise direction.
#     *   **Accept with both hands:**  When offered something (a gift, a drink, etc.), accept it with both hands as a sign of respect.
#     *   **Photography restrictions:** Be mindful of photography restrictions inside temples and Dzongs. Always ask permission before photographing people.
#     *   **Tipping:** Tipping is not mandatory but appreciated for good service (guides, drivers).
#     *   **Avoid public displays of affection.**
#     *   **Polite Communication:** Be mindful, respectful and humble in your speech.
#
# **2. SAFETY & PRACTICAL INFO**
#
# *   **Current Safety Situation:** Bhutan is generally a very safe country with low crime rates. Exercise normal precautions. Be aware of potential road hazards, especially during the rainy season and in mountainous areas.
#
# *   **Visa Requirements:**  All tourists (except Indian, Bangladeshi, and Maldivian passport holders) require a visa.  Visas are typically arranged through a licensed Bhutanese tour operator.  The daily tariff (which includes visa fees, accommodation, food, guide, and transportation) is the primary means of obtaining a visa.
#
# *   **Currency Exchange and Payment Methods:**
#     *   The currency is the Bhutanese Ngultrum (BTN). It is pegged to the Indian Rupee (INR) at a 1:1 ratio. Indian Rupees are widely accepted.
#     *   US Dollars and Euros can be exchanged at banks and some hotels in major cities.
#     *   Credit cards are accepted in larger hotels and some shops, but cash is essential for smaller establishments, markets, and rural areas.  ATMs are available in larger towns, but reliability can vary.
#
# *   **Language Tips:**
#     *   The national language is Dzongkha.
#     *   English is widely spoken, especially in tourist areas.
#     *   Learn a few basic Dzongkha phrases:
#         *   *Kuzu zangpo la* (Hello)
#         *   *Kadinchey la* (Thank you)
#         *   *Gaday bay zhui?* (How are you?)
#
# **3. DAILY ITENARY**
#
# **Important Notes Before Starting:**
# *   *Bhutan's "High Value, Low Impact" Tourism Policy*: Be prepared for a relatively higher daily cost compared to other Asian destinations. The daily tariff is a significant factor.
# *   *Altitude*: Acclimatization is important. Take it easy on the first day and stay hydrated.
# *   *Transportation*: This itinerary assumes you have a private vehicle and driver, as is common for most tourists due to regulations.  Travel times are estimates and can vary based on road conditions.
# *   *Flexibility*: Be prepared to adjust the itinerary based on weather conditions or unforeseen circumstances. Your guide can help with this.
#
# **Day 1: Arrival in Paro & Thimphu (Acclimatization)**
#
# *   *Morning (8:00 AM):* Arrive at Paro International Airport (PBH).  This is one of the most challenging airports in the world to land at, offering stunning views.
# *   *Immigration & Customs (8:30 AM - 9:30 AM):*  Meet your guide and driver.
# *   *Drive to Thimphu (9:30 AM - 11:00 AM):*  (~1.5 hours). Enjoy the scenic drive along the Paro Chhu (river).
# *   *Hotel Check-in (11:00 AM):* Check into your hotel in Thimphu (mid-range options: Hotel Migmar, City Hotel). Relax and acclimatize.
# *   *Lunch (12:30 PM):*  Enjoy a Bhutanese lunch at a local restaurant. Try Ema Datshi (chili cheese stew), the national dish.
# *   *Afternoon (2:00 PM):*  **Buddha Dordenma Statue:** Visit the massive golden Buddha Dordenma statue, offering panoramic views of the Thimphu valley.
# *   *Memorial Chorten (4:00 PM):*  Visit the National Memorial Chorten, a stupa built in memory of the Third Druk Gyalpo.
# *   *Evening (6:00 PM):*  Explore Thimphu town, browse the handicraft shops.
# *   *Dinner (7:30 PM):*  Enjoy dinner at a restaurant in Thimphu.
# *   *Overnight:* Thimphu.
#
# **Day 2: Thimphu Exploration & Hike**
#
# *   *Morning (9:00 AM):* **Takin Preserve (Motithang Takin Preserve):** See the Takin, Bhutan's national animal.
# *   *Hiking to Tango Monastery(10:30 AM):* Hike to Tango Monastery, It is located near Cheri Mountain, north of Thimphu. It was built in its current form in the 17th century by Gyalse Tenzin Rabgye. In 1688, Gyalse Tenzin Rabgye, who was then ruling Bhutan, identified the site as sacred.
# *   *Lunch (1:00 PM):* Have lunch in near Tango Monastery.
# *   *Afternoon (2:30 PM):* **Folk Heritage Museum:** Learn about traditional Bhutanese rural life.
# *   *Textile Museum (4:00 PM):* Discover Bhutan's rich textile traditions.
# *   *Evening (5:30 PM):*  Free time for shopping or relaxing.
# *   *Dinner (7:30 PM):* Enjoy dinner in Thimphu.
# *   *Overnight:* Thimphu.
#
# **Day 3: Punakha - Dochula Pass & Adventure**
#
# *   *Morning (8:00 AM):* Drive to Punakha (~3 hours). The drive is scenic but winding.
# *   *Dochula Pass (9:30 AM):* Stop at Dochula Pass (3,100m/10,200ft). On a clear day, you can see stunning views of the Himalayan mountain range. Visit the 108 chortens (stupas).
# *   *Descend to Punakha (10:30 AM):* Continue driving to Punakha.
# *   *Lunch (12:30 PM):* Have lunch in Punakha.
# *   *Afternoon (2:00 PM):* **Punakha Dzong:** Explore the magnificent Punakha Dzong, located at the confluence of the Pho Chhu and Mo Chhu rivers.
# *   *Suspension Bridge (4:00 PM):* Walk across Bhutan's longest suspension bridge, offering stunning views of the valley.
# *   *Evening (5:00 PM):* Check into your hotel in Punakha (mid-range options: Zhingkham Resort, Damchen Resort).
# *   *Dinner (7:30 PM):* Enjoy dinner in Punakha.
# *   *Overnight:* Punakha.
#
# **Day 4: Tiger's Nest Monastery Hike & Departure**
#
# *   *Early Morning (6:00 AM):* Drive to Paro (~3-4 hours).
# *   *Tiger's Nest Hike (10:00 AM):* Begin the hike to Tiger's Nest Monastery (Paro Taktsang). This is the highlight of the trip. The hike takes approximately 5-6 hours (round trip).
# *   *Lunch (1:00 PM):*  Have lunch at the cafeteria on the way to Tiger's Nest.
# *   *Descend (3:00 PM):* Complete the hike.
# *   *Drive to Paro Airport (5:00 PM):*  Transfer to Paro International Airport for your departure flight.
# *   *Departure (7:00 PM):* Depart from Paro.
#
# **4. FOOD AVAILABILITY**
#
# *   **Bhutanese Cuisine:** Bhutanese food is generally spicy, with chilies being a key ingredient. The national dish is Ema Datshi (chili cheese stew). Other common dishes include Phaksha Paa (pork with chilies), Tshoem (mushrooms), and Momos (dumplings).
# *   **Vegetarian Options:** Vegetarian food is readily available. Bhutanese Buddhists traditionally refrain from killing animals, so vegetarianism is common.  Ema Datshi is often served as a vegetarian option. Many hotels and restaurants will offer vegetable curries, rice, and noodle dishes. Request "vegetarian food" specifically.
# *   **Non-Vegetarian Options:** Pork, chicken, and beef are commonly consumed.
#
# **5. EMERGENCY CONTACTS**
#
# *   **General Emergency Number:** 112
# *   **Police:** 113
# *   **Ambulance:** 112
# *   *   **Tourism Council of Bhutan:** +975 2 323 251
# *   **Embassy/Consulate Information:**
#
#     *   Since Bhutan has diplomatic relations with a limited number of countries, your embassy might not be located in Bhutan.  In that case, contact your embassy in India (New Delhi) for assistance.
#     *   *Example: U.S. Embassy in New Delhi, India:*  +91-11-2419-8000
#
# **Budget Breakdown (Approximate):**
#
# *   *Daily Tariff (4 Days x $200 USD):* $800 (This covers visa, accommodation, food, guide, and transportation).
# *   *Souvenirs and Shopping:* $100
# *   *Tips:* $50
# *   *Miscellaneous Expenses (drinks, snacks):* $50
# *   *Flights:* Approximately $900 from Bangkok to Paro and back.
#
# **Important Considerations:**
#
# *   Book your flights and tour through a licensed operator well in advance, especially if traveling during peak season.
# *   Pack comfortable hiking shoes, layers of clothing (for varying temperatures), sunscreen, a hat, and insect repellent.
# *   Be respectful of Bhutanese culture and traditions.
# *   Enjoy the unique beauty and serenity of Bhutan!
#
#
# ============================================================
# Current travel alerts.....
# ============================================================
# Eroor checking alerts: name 'results' is not defined
#
# ============================================================
# Travel Summary
# Destination : Bhutan
# Duration : 4
# Budget : 2000
# Interests : ['Adaenture']
# Style : mid-range
#
#  Save this plan to file? (y/n): y
#
#  Plan another trip (y/n) : y
# Welcome to Travel buddy...
# ============================================================
# Where do you want to go? Nepal
# How many days? 4
# What's your budget range? (500-1000, midrange, luxury)2000
#
# What are you interested in? (seperate with commas)
# Examples : food, culture, adventure, nature, shopping, history
# Interest: nature
#
# Travel Style
# 1. Backpacker/Budget
# 2. Comfort/Mid-range
# 3. Luxury
# 4. Adventure
# 5. Cultural/Historical
# Choose (1-5): comfort
#
#  Researching Destination Nepal...
# Searching : Nepal travel guide 2025-2026....
# Searching : Nepal best attractions things to do....
# Searching : Nepal travel safety current situation....
# Searching : Nepal weather climate best time to visit....
# Searching : Nepal budget costs accomodation and food....
# Checking current travel alerts... Travel advisory
# Creating your personalizd travel plan....
#
# ============================================================
# Your personalized travel plan is.....
# ============================================================
# Okay, here's a detailed 4-day Nepal travel plan tailored to your interests, budget, and travel style, incorporating the provided research data.
#
# **1. DESTINATION OVERVIEW: Nepal - The Land of the Himalayas**
#
# *   **Brief Description:** Nepal, nestled in the Himalayas, is a land of stunning natural beauty, rich culture, and spiritual significance. Home to eight of the world's ten tallest mountains, including Mount Everest, it's a paradise for nature enthusiasts, trekkers, and those seeking cultural immersion.
# *   **Highlights:**
#     *   **Himalayan Scenery:** Majestic mountain views, including Everest.
#     *   **Cultural Heritage:** Ancient temples, monasteries, and vibrant festivals.
#     *   **Wildlife:** Chitwan National Park, Bardiya National Park.
#     *   **Adventure Activities:** Trekking, paragliding, white-water rafting.
# *   **Best Time to Visit:**  October to December (Autumn) offer the clearest skies, stable weather, and ideal trekking conditions.
# *   **Cultural Tips & Etiquette:**
#     *   **Dress Respectfully:**  Cover shoulders and knees when visiting religious sites.
#     *   **Remove Shoes:**  Always take off your shoes before entering temples and homes.
#     *   **Use Right Hand:**  Use your right hand for eating, giving, and receiving (the left is considered unclean).
#     *   **Bargain Respectfully:** Bargaining is common in markets, but do it politely.
#     *   **Namaste:**  Use "Namaste" (palms together) as a greeting.
#     *   **Photography:** Ask for permission before taking photos of people or religious ceremonies.
#     *   **Public Displays of Affection:** Keep public displays of affection to a minimum.
#
# **2. SAFETY & PRACTICAL INFO**
#
# *   **Current Safety Situation:**
#     *   Exercise a high degree of caution. Petty theft is common, particularly in tourist areas. Monitor local media for any demonstrations or developing situations.
#     *   Avoid demonstrations and crowds.
#     *   Take particular care when walking around Kupandol, Sanepa and Thamel.
# *   **Visa Requirements:**
#     *   Most nationalities require a visa for Nepal. You can obtain a visa on arrival at Tribhuvan International Airport in Kathmandu or at land borders.
#     *   Bring passport-sized photos and cash (USD) for the visa fee. Check the latest requirements on your embassy's website.
# *   **Currency Exchange & Payment Methods:**
#     *   The Nepalese Rupee (NPR) is the local currency.
#     *   You can exchange USD, EUR, and other major currencies at the airport, banks, and money exchange offices in Kathmandu and Pokhara.
#     *   Credit cards are accepted at larger hotels and restaurants, but cash is essential for smaller establishments and markets.
# *   **Language Tips:**
#     *   Nepali is the official language.
#     *   English is widely spoken in tourist areas.
#     *   Learn a few basic Nepali phrases:
#         *   Namaste: Hello/Greetings
#         *   Dhanyabad: Thank you
#         *   Kati ho?: How much?
#         *   Tapaii lai kasto cha?: How are you?
#
# **3. DAILY ITINERARY**
#
# **Assumptions:**
# *   Arrive in Kathmandu (Tribhuvan International Airport - KTM).
# *   Mid-range travel style means comfortable accommodations (3-4 star hotels), occasional tourist-friendly restaurants, and a mix of private transport and local buses.
#
# **Day 1: Arrival in Kathmandu & Cultural Immersion**
#
# *   **Morning (8:00 AM):**
#     *   Arrive at Tribhuvan International Airport (KTM).
#     *   Obtain your visa on arrival.
#     *   Transfer to your hotel in Thamel (tourist hub). (30-45 minutes by taxi/pre-booked transfer – Budget: $15-20)
#     *   Hotel Recommendation: Hotel Arts Kathmandu or similar (Mid-range, approx. $50-70/night).
# *   **Afternoon (12:00 PM):**
#     *   Lunch in Thamel. Try a local restaurant for Dal Bhat (lentil soup, rice, vegetables). (Budget: $5-10)
#     *   Visit Swayambhunath Stupa (Monkey Temple). Explore the stupa and enjoy panoramic views of Kathmandu Valley. (Entry fee: NPR 200, Taxi from Thamel: $5, Time: 2-3 hours).
# *   **Evening (5:00 PM):**
#     *   Explore Thamel: Wander through the bustling streets, browse shops selling handicrafts, and soak in the atmosphere.
#     *   Dinner: Enjoy Nepali cuisine at a restaurant in Thamel. (Budget: $10-15).
#     *   Optional: Enjoy live music at a local bar.
#
# **Day 2: Kathmandu Valley - Heritage & History**
#
# *   **Morning (8:00 AM):**
#     *   Breakfast at your hotel or a local bakery. (Budget: $5-8)
#     *   Visit Pashupatinath Temple, one of the most sacred Hindu temples in the world, located on the banks of the Bagmati River. (Entry fee: NPR 1000, Taxi from Thamel: $8, Time: 2 hours).
# *   **Afternoon (12:00 PM):**
#     *   Lunch near Pashupatinath Temple. (Budget: $5-10)
#     *   Visit Boudhanath Stupa, one of the largest spherical stupas in Nepal and a UNESCO World Heritage Site.  (Entry fee: NPR 400, Walk from Pashupatinath or short taxi ride, Time: 2 hours)
# *   **Evening (5:00 PM):**
#     *   Visit Kathmandu Durbar Square, the historic heart of Kathmandu. Explore the palaces, temples, and courtyards. (Entry fee: NPR 1000, Taxi from Boudhanath: $8, Time: 2-3 hours).
#     *   Dinner: Enjoy a traditional Nepali Thali set at a restaurant in Durbar Square. (Budget: $10-15).
#
# **Day 3: Scenic Flight to Pokhara & Lakeside Serenity**
#
# *   **Morning (7:00 AM):**
#     *   Early breakfast at your hotel. (Budget: $5-8)
#     *   Transfer to Kathmandu Airport for your flight to Pokhara. (Taxi: $8, Flight time: 30 minutes - Book in advance – Budget: $120-150 round trip)
#     *   Note: You can take a tourist bus to Pokhara (6-8 hours), which is cheaper ($10-15), but the flight saves significant time.
# *   **Morning (9:00 AM):**
#     *   Arrive at Pokhara Airport.
#     *   Transfer to your hotel near Lakeside. (Taxi: $5-8)
#     *   Hotel Recommendation: Hotel Pokhara Grande or similar (Mid-range, approx. $60-80/night).
# *   **Afternoon (12:00 PM):**
#     *   Lunch at a lakeside restaurant. (Budget: $8-12)
#     *   Boating on Phewa Lake: Rent a boat and explore the lake. Visit Tal Barahi Temple, located on an island in the lake. (Boat rental: $5-10 per hour, Time: 2-3 hours).
# *   **Evening (5:00 PM):**
#     *   Walk along Lakeside: Enjoy the sunset views over the Annapurna range.
#     *   Dinner: Choose from a variety of restaurants along Lakeside. (Budget: $10-15)
#
# **Day 4: Pokhara - Sunrise, Views & Departure**
#
# *   **Morning (5:00 AM):**
#     *   Early start for a sunrise view from Sarangkot. Hire a taxi to Sarangkot viewpoint. (Taxi: $20-25 round trip, Time: 3-4 hours).
#     *   Enjoy panoramic views of the Annapurna and Dhaulagiri mountain ranges.
# *   **Morning (9:00 AM):**
#     *   Breakfast in Pokhara (Budget: $5-8)
#     *   Visit the International Mountain Museum
# *   **Afternoon (12:00 PM):**
#     *   Lunch in Pokhara (Budget: $8-12)
#     *   Return flight to Kathmandu.
#     *   Transfer to Tribhuvan International Airport for your departure flight. (Taxi: $15-20).
#
# **4. FOOD AVAILABLE**
#
# *   **Nepali Cuisine:**
#     *   **Dal Bhat:** The staple dish – lentil soup, rice, vegetables, and often meat curry.
#     *   **Momo:** Steamed or fried dumplings filled with meat or vegetables.
#     *   **Thukpa:** Noodle soup with vegetables and meat.
#     *   **Chow Mein:** Stir-fried noodles.
#     *   **Sel Roti:** Sweet, ring-shaped rice bread.
# *   **Vegetarian/Vegan Options:**
#     *   Nepal has a large Hindu population, so vegetarian options are readily available.
#     *   **Dal Bhat** can easily be made vegetarian.
#     *   Vegetable momos, vegetable curries, and lentil soups are widely available.
#     *   Many restaurants offer tofu or paneer (Indian cheese) based dishes.
#     *   Vegan travellers should inquire about dairy products used in cooking.
#     *   Western food are also available easily
# *   **Recommended Dishes:**
#     *   **Vegetarian:** Dal Bhat (Vegetable), Vegetable Momo, Thukpa
#     *   **Non-Vegetarian:** Chicken or Mutton Momo, Chicken Curry
#
# **5. EMERGENCY CONTACTS**
#
# *   **Police:** 100
# *   **Ambulance:** 102
# *   **Fire Brigade:** 101
#
# **Budget Breakdown (Approximate):**
#
# *   Flights (Kathmandu-Pokhara return): $240-300
# *   Accommodation (4 nights x $60): $240-320
# *   Food (4 days x $30): $120
# *   Activities/Entrance Fees: $100
# *   Internal Transport (Taxis, buses): $80
# *   Visa: $50
# *   Miscellaneous (Souvenirs, snacks): $100
# *   **Total:** $930-1210
#
# **Notes:**
#
# *   This is a flexible itinerary and can be adjusted based on your preferences.
# *   Pre-booking flights and accommodation, especially during peak season, is highly recommended.
# *   Bargaining is common in Nepal, so don't hesitate to negotiate prices.
# *   Stay hydrated by drinking plenty of water, especially when trekking.
# *   Purchase travel insurance that covers medical emergencies and trip cancellations.
# *   Enjoy your trip to Nepal!
#
#
# ============================================================
# Current travel alerts.....
# ============================================================
# Eroor checking alerts: name 'results' is not defined
#
# ============================================================
# Travel Summary
# Destination : Nepal
# Duration : 4
# Budget : 2000
# Interests : ['nature']
# Style : mid-range
#
#  Save this plan to file? (y/n): y
#
#  Plan another trip (y/n) : y
# Welcome to Travel buddy...
# ============================================================
# Where do you want to go? Mauritius
# How many days? 5
# What's your budget range? (500-1000, midrange, luxury)2000
#
# What are you interested in? (seperate with commas)
# Examples : food, culture, adventure, nature, shopping, history
# Interest: nature
#
# Travel Style
# 1. Backpacker/Budget
# 2. Comfort/Mid-range
# 3. Luxury
# 4. Adventure
# 5. Cultural/Historical
# Choose (1-5): comfort
#
#  Researching Destination Mauritius...
# Searching : Mauritius travel guide 2025-2026....
# Searching : Mauritius best attractions things to do....
# Searching : Mauritius travel safety current situation....
# Searching : Mauritius weather climate best time to visit....
# Searching : Mauritius budget costs accomodation and food....
# Checking current travel alerts... Travel advisory
# Creating your personalizd travel plan....
#
# ============================================================
# Your personalized travel plan is.....
# ============================================================
# Okay, here's a detailed 5-day Mauritius itinerary tailored to your interests, budget, and travel style, incorporating the provided research data:
#
# **1. DESTINATION OVERVIEW**
#
# *   **Description:** Mauritius is a volcanic island nation in the Indian Ocean, east of Madagascar.  It's renowned for its stunning beaches, lagoons, reefs, hiking trails, and diverse cultural influences (Indian, African, French, and Chinese).
# *   **Highlights:** Black River Gorges National Park (hiking, wildlife), Chamarel Seven Coloured Earth, Le Morne Brabant (historical significance, hiking), Île aux Cerfs (beach paradise),  Pamplemousses Botanical Garden.
# *   **Best Time to Visit:** April-May offers pleasant weather, fewer crowds, and potentially better deals on flights and accommodations. November - December is also good, but hotter. Avoid January-March due to cyclone season.
# *   **Cultural Tips and Etiquette:**
#     *   **Greetings:** A handshake is common. For those you know well, a light kiss on both cheeks (French style) is appropriate.
#     *   **Dress:**  Modest dress is appreciated when visiting religious sites (temples, mosques). Swimwear should be confined to beaches and pool areas.
#     *   **Tipping:**  Tipping is not mandatory, but appreciated for good service (around 10%).
#     *   **Respect:** Be respectful of local customs and traditions. Ask permission before taking photos of people.
#     *   **Bargaining:**  Bargaining is acceptable in markets but not in established stores.
#
# **2. SAFETY & PRACTICAL INFO**
#
# *   **Current Safety Situation:**  Mauritius is generally safe. Petty crime (pickpocketing, bag snatching) can occur, especially in tourist areas like Port Louis, Flic en Flac, and Grand Baie. Be vigilant with your belongings. Exercise normal precautions.
# *   **Visa Requirements:** Most nationalities can enter Mauritius visa-free for tourism purposes for a limited period (check the specific requirements for your nationality).  Ensure your passport is valid for at least six months beyond your intended stay.
# *   **Currency Exchange and Payment Methods:** The currency is the Mauritian Rupee (MUR).  Euros and USD are easily exchanged at banks, currency exchange bureaus, and some hotels. Credit cards are widely accepted in hotels, restaurants, and larger stores.  It's a good idea to have some cash for smaller establishments, markets, and tips.
# *   **Language Tips:** The official language is English, but French and Mauritian Creole are widely spoken.  Learning a few basic Creole phrases will be appreciated:
#     *   *Bonjour/Bonsoir:* Hello/Good evening
#     *   *Merci:* Thank you
#     *   *S'il vous plaît:* Please
#     *   *Ki manier?:* How are you?
#     *   *Mo byen, merci:* I'm fine, thank you
#
# **3. DAILY ITINERARY**
#
# *This itinerary assumes a mid-range budget, focusing on nature activities. Accommodation will be around $30/night, and food around $20/day.*
#
# **Day 1: Arrival & West Coast Exploration (Flic en Flac)**
#
# *   **Morning (8:00 AM):** Arrive at Sir Seewoosagur Ramgoolam International Airport (MRU).  Pre-book an airport transfer to Flic en Flac (approx. 1 hour).  Check into your accommodation (consider a guesthouse or budget-friendly hotel).
# *   **Afternoon (12:00 PM):** Lunch at a local restaurant in Flic en Flac (try street food or a casual eatery).
# *   **Afternoon (2:00 PM):** Relax on Flic en Flac beach – one of the longest and most beautiful beaches in Mauritius. Enjoy swimming, sunbathing, or simply strolling along the shore.
# *   **Late Afternoon (5:00 PM):**  Sunset viewing at Flic en Flac beach.
# *   **Evening (7:00 PM):** Dinner at a local restaurant in Flic en Flac (plenty of options for different cuisines).
#
# **Day 2: Black River Gorges National Park & Chamarel**
#
# *   **Morning (8:00 AM):**  Rent a car (approx. $23/day) or hire a taxi for the day (negotiate the price beforehand). Drive to Black River Gorges National Park (approx. 45 minutes from Flic en Flac).
# *   **Morning (9:00 AM):** Hike one of the trails in Black River Gorges National Park. The Macchabee Trail is a good option for moderate fitness levels, offering stunning views. Allow 2-3 hours for the hike. Pack water and snacks.
# *   **Lunch (12:00 PM):** Picnic lunch in the park or have a light meal at a nearby restaurant.
# *   **Afternoon (2:00 PM):** Drive to Chamarel (approx. 30 minutes from the park).
# *   **Afternoon (2:30 PM):** Visit the Chamarel Seven Coloured Earth and Chamarel Waterfall.
# *   **Late Afternoon (4:30 PM):** Optional: Visit the Rhumerie de Chamarel (rum distillery) for a tour and tasting (allow 1-2 hours).
# *   **Evening (7:00 PM):**  Dinner at a restaurant in Chamarel or back in Flic en Flac.
#
# **Day 3: South Coast & Le Morne Brabant**
#
# *   **Morning (9:00 AM):** Drive to Le Morne Brabant (approx. 1 hour from Flic en Flac).
# *   **Morning (10:00 AM):** Hike Le Morne Brabant. This is a challenging hike (allow 3-4 hours, round trip), but the views from the top are incredible. It also has significant historical importance as a refuge for escaped slaves. *Note: The final section requires some climbing and may not be suitable for everyone. Consider your fitness level.*
# *   **Lunch (2:00 PM):** Lunch at a restaurant near Le Morne beach.
# *   **Afternoon (3:00 PM):** Relax on Le Morne beach, known for its calm waters and stunning views.  Optional:  Try watersports (kite surfing, windsurfing) if you're feeling adventurous.
# *   **Late Afternoon (5:00 PM):** Drive to Gris Gris, the southernmost point of Mauritius, known for its dramatic cliffs and powerful waves.
# *   **Evening (7:00 PM):** Dinner at a restaurant along the south coast or back in Flic en Flac.
#
# **Day 4: Île aux Cerfs & East Coast**
#
# *   **Morning (9:00 AM):** Drive to Trou d'Eau Douce (east coast, approx. 1 hour 15 minutes from Flic en Flac).
# *   **Morning (10:30 AM):** Take a boat trip to Île aux Cerfs (Island of Deer). Numerous tour operators offer trips, often including lunch.
# *   **Daytime (11:00 AM - 4:00 PM):**  Enjoy the beaches of Île aux Cerfs. Swim, sunbathe, snorkel, or try watersports. Lunch is typically included in the boat trip.
# *   **Late Afternoon (4:00 PM):** Return to Trou d'Eau Douce.
# *   **Evening (6:00 PM):** Dinner at a restaurant in Trou d'Eau Douce or drive back towards Flic en Flac for more options.
#
# **Day 5: Pamplemousses Botanical Garden & Departure**
#
# *   **Morning (9:00 AM):** Check out of your accommodation. Drive to the Sir Seewoosagur Ramgoolam Botanical Garden (Pamplemousses) (approx. 1 hour from Flic en Flac).
# *   **Morning (10:00 AM):** Explore the botanical garden, home to a vast collection of plants from around the world, including giant water lilies.
# *   **Lunch (12:00 PM):** Lunch at a restaurant near the botanical garden.
# *   **Afternoon (1:30 PM):** Depart from MRU.  Allow at least 3 hours for check-in and security.
#
# **Budget Breakdown (Estimated):**
#
# *   Accommodation (5 nights x $30): $150
# *   Car Rental (3 days x $23): $69
# *   Food (5 days x $20): $100
# *   Activities (Entrance fees, boat trip): $250
# *   Transportation (Airport transfers, fuel): $100
# *   Souvenirs/Miscellaneous: $31
#
# **4. FOOD AVAILABLE**
#
# *   **Cuisine:** Mauritian cuisine is a delicious fusion of Indian, African, French, and Chinese influences. Common dishes include:
#     *   **Curries:**  Chicken, fish, and vegetable curries are popular, often served with rice and roti.
#     *   **Seafood:**  Fresh seafood is abundant, grilled, fried, or in curries.
#     *   **Dholl Puri:**  A type of flatbread filled with ground split peas and spices.
#     *   **Gato Pima:** Chili cakes
#     *   **Mine Frites:** Fried noodles
#     *   **Rougaille:** A tomato-based stew, often with meat or seafood.
#     *   **Palm Heart Salad:** A local delicacy
# *   **Vegetarian/Vegan Options:** Mauritius has a significant Indian population, so vegetarian options are readily available. Look for vegetable curries (bringal, chouchou), dholl puri, and rice-based dishes.  Vegan options may be a bit more limited, but you can find plant-based meals in some restaurants. Ask about ingredients when ordering.
#
# **5. EMERGENCY CONTACTS**
#
# *   **Police:** 999
# *   **Fire:** 995
# *   **Ambulance:** 114
# *   **Your Embassy/Consulate:**  Locate the contact details for your country's embassy or consulate in Mauritius before you travel. You can usually find this information on your government's website.
#
# **Important Notes:**
#
# *   **Book Accommodations in Advance:** Especially during peak season.
# *   **Pack Light:** Comfortable clothing, swimwear, sunscreen, insect repellent, a hat, and good walking shoes are essential.
# *   **Stay Hydrated:** Drink plenty of water, especially when hiking.
# *   **Be Aware of the Sun:** The sun is strong in Mauritius. Use sunscreen and avoid prolonged exposure during the hottest part of the day.
# *   **Check Weather Conditions:** Before hiking or going on boat trips.
# *   **Respect the Environment:** Avoid littering and be mindful of fragile ecosystems.
# *   **Bargain Respectfully:** If you're shopping in markets.
# *   **Enjoy the Island!** Mauritius is a beautiful and welcoming destination.
#
#
# ============================================================
# Current travel alerts.....
# ============================================================
# Eroor checking alerts: name 'results' is not defined
#
# ============================================================
# Travel Summary
# Destination : Mauritius
# Duration : 5
# Budget : 2000
# Interests : ['nature']
# Style : mid-range
#
#  Save this plan to file? (y/n): n
#
#  Plan another trip (y/n) : n
# Happy travels!
